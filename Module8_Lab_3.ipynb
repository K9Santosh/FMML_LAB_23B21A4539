# %% [markdown]
# <a href="https://colab.research.google.com/github/K9Santosh/FMML_LAB_23B21A4539/blob/main/Module8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-17 15:20:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  58.3MB/s    in 1.2s
#
# 2025-03-17 15:20:44 (58.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 30142  1711.07827v1  In this paper, an efficient implementation for...    cs
# 35653   1012.5594v1  The three laws of Robotics first appeared toge...    cs
# 11170   1411.4070v1  Research on probabilistic models of networks n...  stat
# 10767   1402.2594v1  We establish optimal rates for online regressi...  stat
# 5497    1205.1240v1  In this paper, we propose an unifying view of ...  stat
# ...             ...                                                ...   ...
# 32085   1205.4698v2  We introduce into the classical perceptron alg...    cs
# 25583  1510.03125v1  Traffic scene perception (TSP) aims to real-ti...    cs
# 5055   1801.01968v3  The research on deep reinforcement learning wh...    cs
# 38268  1506.08789v1  Requirements traceability is an essential step...    cs
# 21985   1307.2715v1  Community detection in graphs has been the sub...  stat
#
#                                                    title  year  \
# 30142  Efficient Implementation of a Recognition Syst...  2017
# 35653                             The Ethics of Robotics  2010
# 11170  A unified view of generative models for networ...  2014
# 10767                    Online Nonparametric Regression  2014
# 5497       Convex Relaxation for Combinatorial Penalties  2012
# ...                                                  ...   ...
# 32085  The Role of Weight Shrinking in Large Margin P...  2012
# 25583  Fast detection of multiple objects in traffic ...  2015
# 5055   Faster Deep Q-learning using Neural Episodic C...  2018
# 38268          Requirement Tracing using Term Extraction  2015
# 21985  Optimisation dans la détection de communautés ...  2013
#
#                                                 keywords
# 30142  [efficient, implementation, recognition, optim...
# 35653  [runaround, mentioned, depiction, simplistic, ...
# 11170  [probabilistic, including, sociology, statisti...
# 10767  [establish, regression, arbitrary, regression,...
# 5497   [structured, situation, simultaneously, penali...
# ...                                                  ...
# 32085  [introduce, classical, perceptron, algorithm, ...
# 25583  [perception, environment, information, detecti...
# 5055   [reinforcement, estimates, attracted, research...
# 38268  [requirements, traceability, essential, develo...
# 21985  [community, detection, algorithms, modularity,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 30142    [efficient, implementation, recognition, optim...
# 35653    [runaround, mentioned, depiction, simplistic, ...
# 11170    [probabilistic, including, sociology, statisti...
# 10767    [establish, regression, arbitrary, regression,...
# 5497     [structured, situation, simultaneously, penali...
#                                ...
# 21287    [optimization, parameters, convergence, propos...
# 7837     [efficiency, practical, applications, collecti...
# 3871     [efficiency, functions, classification, partic...
# 11418    [clustering, relaxation, clustering, hierarchi...
# 5205     [empirical, investigation, interaction, discre...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8795 words.
# Out of those 4592 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cfd2474f-b5d8-42f1-8f1d-72ee3e5dbc2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfd2474f-b5d8-42f1-8f1d-72ee3e5dbc2c")) {                    Plotly.newPlot(                        "cfd2474f-b5d8-42f1-8f1d-72ee3e5dbc2c",                        [{"x":["computational","recognition","performance","illumination","increased","generated","efficient","improvement","optimizations","evaluated","eliminated","exploited","information","clustering","variations","prototypes","algorithm","expression","embedding","separable","complexity","partitioning","significant","unimportant","implementation","classifiers","convolved","approximations","revolution","something","surpassed","predicted","depiction","simplistic","replacing","beginning","mentioned","concluded","evolution","intelligence","represent","understand","ourselves","advancements","phenomenal","intelligent","artificial","techniques","opportunities","conditional","including","fundamental","structure","probability","generally","philosophical","interdisciplinary","interactions","biological","theoretical","interpretability","highlights","diversity","development","empirically","sociology","probabilistic","optimization","challenges","statistics","disparate","motivated","similarities","different","inhibited","emphasized","generative","attributes","developed","underlying","differences","frequently","transition","sridharan","encountered","interesting","nonparametric","established","analogous","sequential","forecaster","designing","algorithms","phenomenon","functions","establish","statistical","forecasters","computationally","introduced","illustrate","arbitrary","empirical","situation","regression","algorithmic","relaxation","combinatorial","simultaneously","structured","represents","representations","penalties","regularized","submodular","relaxations","introduce","parameter","tightness","characterizes","penalized","knowledge","inference","resulting","difference","elaborate","decomposition","distinctions","associated","preliminary","distribution","evaluation","probabilities","considers","unfortunately","approximation","procedure","management","categorical","consisting","predictive","diagnosis","effective","extracting","positives","components","surveillance","minimizing","selection","strategies","identification","objective","methodologies","negatives","laboratory","alternating","methodology","influential","generating","imputation","specifically","available","meaningful","experiment","languages","handcrafted","constrained","parameters","crosslingual","architecture","annotated","approaches","character","completely","principle","incorporate","desirable","representation","classifier","partially","sequentially","advantage","analyzing","discrimination","collected","unlabeled","observations","equivalents","simulated","applications","framework","transducers","morphological","technology","important","morphology","linguistics","developing","formation","processing"],"y":[272,378,831,28,33,180,426,166,4,128,4,33,717,130,78,8,822,51,121,20,210,20,221,3,144,124,2,27,3,6,3,48,2,2,17,13,19,4,61,82,128,79,3,8,5,61,119,372,15,98,249,72,348,186,65,3,3,87,42,177,22,9,43,120,77,1,140,313,126,75,5,57,39,728,0,3,125,78,189,109,56,32,24,1,16,69,12,46,7,67,3,48,621,26,228,53,164,1,96,126,56,98,155,36,123,32,16,34,111,100,43,249,5,39,11,7,358,100,1,14,5,353,196,156,65,6,60,4,116,48,206,250,55,35,43,119,118,41,13,40,59,38,264,46,15,121,31,32,144,86,96,147,15,6,7,23,79,7,122,2,163,300,54,68,100,11,64,224,2,268,66,427,51,46,56,67,30,389,148,49,17,82,63,15,57,40,66,4,62,431,558,3,24,57,328,15,16,58,14,271],"type":"bar"},{"x":["computational","recognition","performance","illumination","increased","generated","effici ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4592,), (4592, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style='background-color:rgba(255, 0, 0, 0.425925925925926);'>Distributions</span> <span style=''>for</span> <span style=''>Trees</span> <span style='background-color:rgba(0, 255, 0, 0.36438356164383556);'>Representations</span> <span style='background-color:rgba(255, 0, 0, 0.35313531353135313);'>Inference</span> <span style=''>and</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.425925925925926);'>distributions</span> <span style=''>over</span> <span style=''>free</span> <span style=''>algebras</span> <span style=''>of</span> <span style=''>trees</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style='background-color:rgba(255, 0, 0, 0.425925925925926);'>distributions</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>(formal</span> <span style=''>power)</span> <span style=''>tree</span> <span style=''>series</span> <span style=''>Berstel</span> <span style=''>et</span> <span style=''>al</span> <span style=''>82</span> <span style=''>Esik</span> <span style=''>et</span> <span style=''>al</span> <span style=''>03</span> <span style=''>ie</span> <span style=''>mappings</span> <span style=''>from</span> <span style=''>trees</span> <span style=''>to</span> <span style=''>a</span> <span style=''>semiring</span> <span style=''>K</span> <span style=''>A</span> <span style=''>widely</span> <span style=''>studied</span> <span style=''>class</span> <span style=''>of</span> <span style=''>tree</span> <span style=''>series</span> <span style=''>is</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>rational</span> <span style=''>(or</span> <span style=''>recognizable)</span> <span style=''>tree</span> <span style=''>series</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>defined</span> <span style=''>either</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algebraic</span> <span style=''>way</span> <span style=''>or</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>multiplicity</span> <span style=''>tree</span> <span style=''>automata</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algebraic</span> <span style='background-color:rgba(0, 255, 0, 0.43542435424354237);'>representation</span> <span style=''>is</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convenient</span> <span style=''>to</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.425925925925926);'>distributions</span> <span style=''>over</span> <span style=''>a</span> <span style=''>free</span> <span style=''>algebra</span> <span style=''>of</span> <span style=''>trees</span> <span style=''>First</span> <span style=''>as</span> <span style=''>in</span> <span style=''>the</span> <span style=''>string</span> <span style=''>case</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algebraic</span> <span style='background-color:rgba(0, 255, 0, 0.43542435424354237);'>representation</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>design</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>New</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Building</span> <span style=''>the</span> <span style=''>Interindustry</span> <span style=''>Input</span> <span style=''>Output</span> <span style=''>Table</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interdependence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industries</span> <span style=''>in</span> <span style=''>an</span> <span style=''>economy</span> <span style=''>by</span> <span style=''>applying</span> <span style=''>data</span> <span style=''>science</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style=''>interfirm</span> <span style=''>buyer</span> <span style=''>seller</span> <span style=''>network</span> <span style=''>data</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interdependence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industries</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncovering</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>block</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>network</span> <span style=''>science</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>To</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>with</span> <span style=''>greater</span> <span style=''>accuracy</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>block</span> <span style=''>model</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style=''>node</span> <span style=''>textual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbounded</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industries</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>among</span> <span style=''>them</span> <span style=''>The</span> <span style=''>latter</span> <span style=''>task</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accomplished</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restaurant</span> <span style=''>process</span> <span style=''>to</span> <span style=''>two</span> <span style='background-color:rgba(0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Accelerated</span> <span style=''>Variance</span> <span style=''>Reduced</span> <span style='background-color:rgba(255, 0, 0, 0.3634204275534443);'>Stochastic</span> <span style=''>ADMM</span> <br/><br/><span style=''>Recently</span> <span style=''>many</span> <span style=''>variance</span> <span style=''>reduced</span> <span style='background-color:rgba(255, 0, 0, 0.3634204275534443);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multipliers</span> <span style=''>(ADMM)</span> <span style=''>methods</span> <span style=''>(eg</span> <span style=''>SAG</span> <span style=''>ADMM</span> <span style=''>SDCA</span> <span style=''>ADMM</span> <span style=''>and</span> <span style=''>SVRG</span> <span style=''>ADMM)</span> <span style=''>have</span> <span style=''>made</span> <span style=''>exciting</span> <span style=''>progress</span> <span style=''>such</span> <span style=''>as</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>the</span> <span style=''>best</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>for</span> <span style=''>general</span> <span style=''>convex</span> <span style=''>problems</span> <span style=''>is</span> <span style=''>O(1T)</span> <span style=''>as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>O(1T2)</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerated</span> <span style=''>batch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>where</span> <span style=''>T</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>Thus</span> <span style=''>there</span> <span style=''>still</span> <span style=''>remains</span> <span style=''>a</span> <span style=''>gap</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>between</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3634204275534443);'>stochastic</span> <span style=''>ADMM</span> <span style=''>and</span> <span style=''>batch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>To</span> <span style=''>bridge</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>momentum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>acceleration</span> <span style=''>trick</span> <span style=''>for</span> <span style=''>batch</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3634204275534443);'>stochastic</span> <span style=''>variance</span> <span style=''>reduced</span> <span style=''>gradient</span> <span style=''>based</span> <span style=''>ADMM</span> <span style=''>(SVRG</span> <span style=''>ADMM)</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerated</span> <span style=''>(ASVRG</span> <span style=''>ADMM)</span> <span style=''>method ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximations</span> <span style=''>to</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Operators</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processing</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>a</span> <span style=''>general</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>(LDR)</span> <span style=''>operator</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>A</span> <span style=''>in</span> <span style=''>mathbbRm</span> <span style=''>times</span> <span style=''>n</span> <span style=''>with</span> <span style=''>m</span> <span style=''>n</span> <span style=''>by</span> <span style=''>a</span> <span style=''>partial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>circulant</span> <span style=''>matrix</span> <span style=''>with</span> <span style=''>rows</span> <span style=''>related</span> <span style=''>by</span> <span style=''>circular</span> <span style=''>shifts</span> <span style=''>Partial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>circulant</span> <span style=''>matrices</span> <span style=''>admit</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementations</span> <span style=''>via</span> <span style=''>Fourier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>methods</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operations</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigation</span> <span style=''>here</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>a</span> <span style=''>desire</span> <span style=''>to</span> <span style=''>leverage</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>in</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>tasks</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>result</span> <span style=''>that</span> <span style=''>most</span> <span style=''>large</span> <span style=''>LDR</span> <span style=''>matrices</span> <span style=''>(whose</span> <span style=''>row</span> <span style=''>spaces</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniformly</span> <span style=''>distributed)</span> <span style=''>in</span> <span style=''>fact</span> <span style=''>cannot</span> <span style=''>be</span> <span style ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06258840169731258)
# 	knowledge (0.12482319660537482)
# 	architecture (0.09476661951909476)
# 	experimental (0.14391796322489392)
# 	representation (0.13755304101838756)
# 	information (0.25353606789250355)
# 	detection (0.1304809052333805)
# 	different (0.25742574257425743)
# 	recognition (0.13366336633663367)
# 	convolutional (0.1379066478076379)
#
# Some Statistics words are:
# 	variables (0.14046653144016227)
# 	estimation (0.16886409736308317)
# 	stochastic (0.14553752535496958)
# 	theoretical (0.1627789046653144)
# 	statistical (0.16024340770791076)
# 	algorithm (0.39401622718052737)
# 	distribution (0.1876267748478702)
# 	dimensional (0.18356997971602435)
# 	inference (0.2079107505070994)
# 	regression (0.18864097363083165)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e4803556-5eba-428c-85c9-5f3cbed365d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4803556-5eba-428c-85c9-5f3cbed365d0")) {                    Plotly.newPlot(                        "e4803556-5eba-428c-85c9-5f3cbed365d0",                        [{"x":["computational","recognition","performance","illumination","increased","generated","efficient","improvement","optimizations","evaluated","eliminated","exploited","information","clustering","variations","prototypes","algorithm","expression","embedding","separable","complexity","partitioning","significant","unimportant","implementation","classifiers","convolved","approximations","revolution","something","surpassed","predicted","depiction","simplistic","replacing","beginning","mentioned","concluded","evolution","intelligence","represent","understand","ourselves","advancements","phenomenal","intelligent","artificial","techniques","opportunities","conditional","including","fundamental","structure","probability","generally","philosophical","interdisciplinary","interactions","biological","theoretical","interpretability","highlights","diversity","development","empirically","sociology","probabilistic","optimization","challenges","statistics","disparate","motivated","similarities","different","inhibited","emphasized","generative","attributes","developed","underlying","differences","frequently","transition","sridharan","encountered","interesting","nonparametric","established","analogous","sequential","forecaster","designing","algorithms","phenomenon","functions","establish","statistical","forecasters","computationally","introduced","illustrate","arbitrary","empirical","situation","regression","algorithmic","relaxation","combinatorial","simultaneously","structured","represents","representations","penalties","regularized","submodular","relaxations","introduce","parameter","tightness","characterizes","penalized","knowledge","inference","resulting","difference","elaborate","decomposition","distinctions","associated","preliminary","distribution","evaluation","probabilities","considers","unfortunately","approximation","procedure","management","categorical","consisting","predictive","diagnosis","effective","extracting","positives","components","surveillance","minimizing","selection","strategies","identification","objective","methodologies","negatives","laboratory","alternating","methodology","influential","generating","imputation","specifically","available","meaningful","experiment","languages","handcrafted","constrained","parameters","crosslingual","architecture","annotated","approaches","character","completely","principle","incorporate","desirable","representation","classifier","partially","sequentially","advantage","analyzing","discrimination","collected","unlabeled","observations","equivalents","simulated","applications","framework","transducers","morphological","technology","important","morphology","linguistics","developing","formation","processing","equivalent","proposing","convolutional","backpropagation","resolution","reasonably","optimizing","unsupervised","classification","multilayer","demonstrating","supervision","competitive","applicability","reproducing","improvements","prediction","decoupled","supervised","traditional","dominated","controller","automatic","contradictory","demonstrate","evolutionary","fractional","effectiveness","augmented","regulator","comparative","hierarchically","interpolated","combination","standardizing","hypothesis","describes","translation","submitted","competition","transliteration","dialectal","operation","construction","infeasible","superiority","influencing","approximate","alternative","possessing","euclidean","convergence","comparable","separa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inhibited
# 	econometrics
# 	metropolis
# 	conjugacy
# 	equitable
# 	equitability
# 	connectome
# 	morgenstern
# 	conveniently
# 	katehakis
# 	penalizations
# 	majorization
# 	indiscriminate
# 	capitalization
# 	correspondingly
# 	multiplying
# 	instabilities
# 	metabolic
# 	prioritization
# 	anopheles
# Some words which never appear in Statistics papers:
# 	unimportant
# 	surpassed
# 	depiction
# 	crosslingual
# 	transducers
# 	contradictory
# 	regulator
# 	transliteration
# 	dialectal
# 	crossover
# 	chromosome
# 	noticeably
# 	metaheuristic
# 	leadingones
# 	offspring
# 	reproduction
# 	articulated
# 	aesthetically
# 	reachability
# 	automaton

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.042102701387199e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7483333333333333
